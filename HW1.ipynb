# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
lr_model = LinearRegression(normalize=True)

# %% [markdown]
# # 1_1

# %%
x = np.random.rand(5, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)
y_line = lr_model.predict(x_line)

plt.plot(x, y, 'bo')
plt.plot(x_line, y_line, 'r--')

# %% [markdown]
# # 1-2

# %%
x = np.random.rand(10, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)
y_line = lr_model.predict(x_line)

plt.plot(x, y, 'bo')
plt.plot(x_line, y_line, 'r--')

# %% [markdown]
# # 1_3

# %%
x = np.random.rand(25, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)
y_line = lr_model.predict(x_line)

plt.plot(x, y, 'bo')
plt.plot(x_line, y_line, 'r--')

# %% [markdown]
# # 1_4

# %%
x = np.random.rand(100, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)
y_line = lr_model.predict(x_line)

plt.plot(x, y, 'bo')
plt.plot(x_line, y_line, 'r--')

# %% [markdown]
# # 2_1

# %%
x = np.random.rand(5, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

x = np.hstack((x, x**2, x**3, x**4))

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)
x_line = np.hstack((x_line, x_line**2, x_line**3, x_line**4))
y_line = lr_model.predict(x_line)

plt.plot(x[:, 0], y, 'bo')
plt.plot(x_line[:, 0], y_line, 'r--')

# %% [markdown]
# # 2_2

# %%
x = np.random.rand(10, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

x = np.hstack((x, x**2, x**3, x**4))

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)
x_line = np.hstack((x_line, x_line**2, x_line**3, x_line**4))
y_line = lr_model.predict(x_line)

plt.plot(x[:, 0], y, 'bo')
plt.plot(x_line[:, 0], y_line, 'r--')

# %% [markdown]
# # 2_3

# %%
x = np.random.rand(25, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

x = np.hstack((x, x**2, x**3, x**4))

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)
x_line = np.hstack((x_line, x_line**2, x_line**3, x_line**4))
y_line = lr_model.predict(x_line)

plt.plot(x[:, 0], y, 'bo')
plt.plot(x_line[:, 0], y_line, 'r--')

# %% [markdown]
# # 2_4

# %%
x = np.random.rand(100, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

x = np.hstack((x, x**2, x**3, x**4))

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)
x_line = np.hstack((x_line, x_line**2, x_line**3, x_line**4))
y_line = lr_model.predict(x_line)

plt.plot(x[:, 0], y, 'bo')
plt.plot(x_line[:, 0], y_line, 'r--')

# %% [markdown]
# # 3_1

# %%
x = np.random.rand(5, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

for i in range(2,17):
    z = x[:, 0].reshape(-1, 1)
    x = np.hstack((x, z**i))

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)

for i in range(2,17):
    z_line = x_line[:, 0].reshape(-1, 1)
    x_line = np.hstack((x_line, z_line**i))

y_line = lr_model.predict(x_line)

plt.plot(x[:, 0], y, 'bo')
plt.plot(x_line[:, 0], y_line, 'r--')

# %% [markdown]
# # 3_2

# %%
x = np.random.rand(10, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

for i in range(2,17):
    z = x[:, 0].reshape(-1, 1)
    x = np.hstack((x, z**i))

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)

for i in range(2,17):
    z_line = x_line[:, 0].reshape(-1, 1)
    x_line = np.hstack((x_line, z_line**i))

y_line = lr_model.predict(x_line)

plt.plot(x[:, 0], y, 'bo')
plt.plot(x_line[:, 0], y_line, 'r--')

# %% [markdown]
# # 3_3

# %%
x = np.random.rand(25, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

for i in range(2,17):
    z = x[:, 0].reshape(-1, 1)
    x = np.hstack((x, z**i))

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)

for i in range(2,17):
    z_line = x_line[:, 0].reshape(-1, 1)
    x_line = np.hstack((x_line, z_line**i))

y_line = lr_model.predict(x_line)

plt.plot(x[:, 0], y, 'bo')
plt.plot(x_line[:, 0], y_line, 'r--')

# %% [markdown]
# # 3_4

# %%
x = np.random.rand(100, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

for i in range(2,17):
    z = x[:, 0].reshape(-1, 1)
    x = np.hstack((x, z**i))

lr_model.fit(x, y)

x_line = np.arange(0, 20, 0.1).reshape(-1, 1)

for i in range(2,17):
    z_line = x_line[:, 0].reshape(-1, 1)
    x_line = np.hstack((x_line, z_line**i))

y_line = lr_model.predict(x_line)

plt.plot(x[:, 0], y, 'bo')
plt.plot(x_line[:, 0], y_line, 'r--')

# %% [markdown]
# # 4

# %%
#5 data
x = np.random.rand(5, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

I_5 = []
MSE_5 = []

for i in range(1,11):
    lr_model.fit(x, y)
    I_5.append(i)
    h = lr_model.predict(x)
    mse = np.mean((y - h) ** 2) / 2
    MSE_5.append(mse)
    if i!= 1:
        z = x[:, 0].reshape(-1, 1)
        x = np.hstack((x, z**i))

        
        
#10 data       
x = np.random.rand(10, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

I_10 = []
MSE_10 = []

for i in range(1,11):
    lr_model.fit(x, y)
    I_10.append(i)
    h = lr_model.predict(x)
    mse = np.mean((y - h) ** 2) / 2
    MSE_10.append(mse)
    if i!= 1:
        z = x[:, 0].reshape(-1, 1)
        x = np.hstack((x, z**i))

        
        
#25 data       
x = np.random.rand(25, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

I_25 = []
MSE_25 = []

for i in range(1,11):
    lr_model.fit(x, y)
    I_25.append(i)
    h = lr_model.predict(x)
    mse = np.mean((y - h) ** 2) / 2
    MSE_25.append(mse)
    if i!= 1:
        z = x[:, 0].reshape(-1, 1)
        x = np.hstack((x, z**i))

        
        
#100 data       
x = np.random.rand(100, 1) * 20
y = 2.358 * x - 3.121
y = y + np.random.normal(scale=3, size=y.shape)

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

I_100 = []
MSE_100 = []

for i in range(1,11):
    lr_model.fit(x, y)
    I_100.append(i)
    h = lr_model.predict(x)
    mse = np.mean((y - h) ** 2) / 2
    MSE_100.append(mse)
    if i!= 1:
        z = x[:, 0].reshape(-1, 1)
        x = np.hstack((x, z**i))

        
        
        
plt.plot(I_5, MSE_5, 'r-o')
plt.plot(I_10, MSE_10, 'g-o')
plt.plot(I_25, MSE_25, 'b-o')
plt.plot(I_100, MSE_100, 'y-o')

plt.xlabel ('Number of X^')
plt.ylabel ('MSE')
plt.legend (['5 Data', '10 Data', '25 Data', '100 Data'])
print(MSE_5)
# Out:
# [4.789601346515864, 4.789601346515864, 0.6446896403965707, 0.0003341676076956268, 2.1835669856517608e-28, 1.9011547815826386e-29, 4.1099653162014716e-29, 8.235707850507364e-29, 6.563322731438818e-29, 1.8380459091649576e-29]
